# %% [markdown]
# <a href="https://colab.research.google.com/github/Abash05/PekkasPlayhouse-Data-Royale/blob/main/PekkasPlayhouse_DataRoyale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = '/content/drive/MyDrive/battles.csv'

# %%
df = pd.read_csv(data_path, nrows= 395645)

# %%
df.head()
# Out:
#    Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 0           0  2020-12-07 07:00:00+00:00  54000049.0   72000201.0
# 1           1  2020-12-07 07:00:00+00:00  54000049.0   72000201.0
# 2           2  2020-12-07 07:00:02+00:00  54000049.0   72000201.0
# 3           3  2020-12-07 07:00:03+00:00  54000049.0   72000201.0
# 4           4  2020-12-07 07:00:06+00:00  54000049.0   72000201.0
#
#    average.startingTrophies  winner.tag  winner.startingTrophies  \
# 0                    6590.0  #28RR8PJP0                   6581.0
# 1                    5582.5   #YV9VQUVP                   5592.0
# 2                    5684.0  #LPR2G0Q9L                   5678.0
# 3                    6031.0  #2GL899VCJ                   6035.0
# 4                    5140.0  #9Y2YJPGG2                   5140.0
#
#    winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 0                 31.0            2.0                     4768.0  ...
# 1                 28.0            3.0                     2014.0  ...
# 2                 31.0            3.0                     5304.0  ...
# 3                 29.0            2.0                     3368.0  ...
# 4                 30.0            3.0                     1507.0  ...
#
#                                     loser.cards.list loser.totalcard.level  \
# 0  [26000000, 26000026, 26000030, 26000041, 27000...                   104
# 1  [26000000, 26000003, 26000007, 26000011, 26000...                   104
# 2  [26000011, 26000026, 26000030, 26000041, 27000...                   103
# 3  [26000032, 26000040, 26000041, 26000049, 26000...                   104
# 4  [26000012, 26000024, 26000045, 26000056, 26000...                    93
#
#    loser.troop.count loser.structure.count  loser.spell.count  \
# 0                  4                     1                  3
# 1                  6                     0                  2
# 2                  4                     1                  3
# 3                  6                     1                  1
# 4                  5                     1                  2
#
#    loser.common.count  loser.rare.count  loser.epic.count  \
# 0                   4                 1                 1
# 1                   2                 3                 3
# 2                   3                 2                 2
# 3                   3                 2                 1
# 4                   3                 1                 4
#
#   loser.legendary.count  loser.elixir.average
# 0                     2                 3.125
# 1                     0                 4.125
# 2                     1                 2.875
# 3                     2                 3.375
# 4                     0                 3.875
#
# [5 rows x 74 columns]

# %%
df.tail()
# Out:
#         Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 395640      395640  2020-12-15 23:11:57+00:00  54000050.0   72000006.0
# 395641      395641  2020-12-15 23:11:58+00:00  54000050.0   72000006.0
# 395642      395642  2020-12-15 23:11:59+00:00  54000050.0   72000006.0
# 395643      395643  2020-12-15 23:12:01+00:00  54000050.0   72000006.0
# 395644      395644  2020-12-15 23:12:03+00:00  54000050.0   72000006.0
#
#         average.startingTrophies  winner.tag  winner.startingTrophies  \
# 395640                    5241.5  #2YP20RU08                   5230.0
# 395641                    5578.0  #2URGULQRG                   5580.0
# 395642                    4808.5    #22JCPYL                   4813.0
# 395643                    4984.0  #2992PJPG9                   4988.0
# 395644                    4835.0   #C088LYRV                   4827.0
#
#         winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 395640                 31.0            1.0                     5832.0  ...
# 395641                 29.0            1.0                     4709.0  ...
# 395642                 29.0            1.0                     5832.0  ...
# 395643                 29.0            2.0                     4174.0  ...
# 395644                 31.0            2.0                     4340.0  ...
#
#                                          loser.cards.list  \
# 395640  [26000012, 26000017, 26000020, 26000021, 26000...
# 395641  [26000000, 26000014, 26000019, 26000054, 27000...
# 395642  [26000000, 26000017, 26000027, 26000043, 26000...
# 395643  [26000009, 26000015, 26000035, 26000039, 26000...
# 395644  [26000001, 26000007, 26000021, 26000027, 26000...
#
#        loser.totalcard.level  loser.troop.count loser.structure.count  \
# 395640                   104                  6                     1
# 395641                   103                  4                     1
# 395642                    99                  7                     0
# 395643                   101                  5                     0
# 395644                   104                  6                     0
#
#         loser.spell.count  loser.common.count  loser.rare.count  \
# 395640                  1                   3                 2
# 395641                  3                   3                 1
# 395642                  1                   3                 1
# 395643                  3                   0                 1
# 395644                  2                   2                 3
#
#         loser.epic.count loser.legendary.count  loser.elixir.average
# 395640                 2                     1                 4.000
# 395641                 3                     1                 3.625
# 395642                 3                     1                 4.375
# 395643                 5                     2                 4.250
# 395644                 2                     1                 3.625
#
# [5 rows x 74 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 74 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Unnamed: 0                      1000000 non-null  int64
#  1   battleTime                      1000000 non-null  object
#  2   arena.id                        1000000 non-null  float64
#  3   gameMode.id                     1000000 non-null  float64
#  4   average.startingTrophies        1000000 non-null  float64
#  5   winner.tag                      1000000 non-null  object
#  6   winner.startingTrophies         1000000 non-null  float64
#  7   winner.trophyChange             1000000 non-null  float64
#  8   winner.crowns                   1000000 non-null  float64
#  9   winner.kingTowerHitPoints       1000000 non-null  float64
#  10  winner.princessTowersHitPoints  980244 non-null   object
#  11  winner.clan.tag                 993843 non-null   object
#  12  winner.clan.badgeId             993843 non-null   float64
#  13  loser.tag                       1000000 non-null  object
#  14  loser.startingTrophies          1000000 non-null  float64
#  15  loser.trophyChange              1000000 non-null  float64
#  16  loser.crowns                    1000000 non-null  float64
#  17  loser.kingTowerHitPoints        723915 non-null   float64
#  18  loser.clan.tag                  920862 non-null   object
#  19  loser.clan.badgeId              920862 non-null   float64
#  20  loser.princessTowersHitPoints   486221 non-null   object
#  21  tournamentTag                   0 non-null        float64
#  22  winner.card1.id                 1000000 non-null  int64
#  23  winner.card1.level              1000000 non-null  int64
#  24  winner.card2.id                 1000000 non-null  int64
#  25  winner.card2.level              1000000 non-null  int64
#  26  winner.card3.id                 1000000 non-null  int64
#  27  winner.card3.level              1000000 non-null  int64
#  28  winner.card4.id                 1000000 non-null  int64
#  29  winner.card4.level              1000000 non-null  int64
#  30  winner.card5.id                 1000000 non-null  int64
#  31  winner.card5.level              1000000 non-null  int64
#  32  winner.card6.id                 1000000 non-null  int64
#  33  winner.card6.level              1000000 non-null  int64
#  34  winner.card7.id                 1000000 non-null  int64
#  35  winner.card7.level              1000000 non-null  int64
#  36  winner.card8.id                 1000000 non-null  int64
#  37  winner.card8.level              1000000 non-null  int64
#  38  winner.cards.list               1000000 non-null  object
#  39  winner.totalcard.level          1000000 non-null  int64
#  40  winner.troop.count              1000000 non-null  int64
#  41  winner.structure.count          1000000 non-null  int64
#  42  winner.spell.count              1000000 non-null  int64
#  43  winner.common.count             1000000 non-null  int64
#  44  winner.rare.count               1000000 non-null  int64
#  45  winner.epic.count               1000000 non-null  int64
#  46  winner.legendary.count          1000000 non-null  int64
#  47  winner.elixir.average           1000000 non-null  float64
#  48  loser.card1.id                  1000000 non-null  int64
#  49  loser.card1.level               1000000 non-null  int64
#  50  loser.card2.id                  1000000 non-null  int64
#  51  loser.card2.level               1000000 non-null  int64
#  52  loser.card3.id                  1000000 non-null  int64
#  53  loser.card3.level               1000000 non-null  int64
#  54  loser.card4.id                  1000000 non-null  int64
#  55  loser.card4.level               1000000 non-null  int64
#  56  loser.card5.id                  1000000 non-null  int64
#  57  loser.card5.level               1000000 non-null  int64
#  58  loser.card6.id                  1000000 non-null  int64
#  59  loser.card6.level               1000000 non-null  int64
#  60  loser.card7.id                  1000000 non-null  int64
#  61  loser.card7.level               1000000 non-null  int64
#  62  loser.card8.id                  1000000 non-null  int64
#  63  loser.card8.level               1000000 non-null  int64
#  64  loser.cards.list                1000000 non-null  object
#  65  loser.totalcard.level           1000000 non-null  int64
#  66  loser.troop.count               1000000 non-null  int64
#  67  loser.structure.count           1000000 non-null  int64
#  68  loser.spell.count               1000000 non-null  int64
#  69  loser.common.count              1000000 non-null  int64
#  70  loser.rare.count                1000000 non-null  int64
#  71  loser.epic.count                1000000 non-null  int64
#  72  loser.legendary.count           1000000 non-null  int64
#  73  loser.elixir.average            1000000 non-null  float64
# dtypes: float64(16), int64(49), object(9)
# memory usage: 564.6+ MB

# %%
# card levels/rarity, elixir, deck makeup, individual card data (most used, most wins, etc.) problem statement (best deck or most trophies won from a certain arena, hard counter cards (look into most popular cards and most winning cards?
# Out:
# unzip:  cannot find or open battles, battles.zip or battles.ZIP.

# %%
cutoff = '2020-12-09'
df_before = df[df['battleTime'] < cutoff]
df_after  = df[df['battleTime'] >= cutoff]

# %%
display(df_before.head())
display(df_before.tail())
display(df_after.head())
display(df_after.tail())
# Out:
# dfBefore head:
#    Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 0           0  2020-12-07 07:00:00+00:00  54000049.0   72000201.0
# 1           1  2020-12-07 07:00:00+00:00  54000049.0   72000201.0
# 2           2  2020-12-07 07:00:02+00:00  54000049.0   72000201.0
# 3           3  2020-12-07 07:00:03+00:00  54000049.0   72000201.0
# 4           4  2020-12-07 07:00:06+00:00  54000049.0   72000201.0
#
#    average.startingTrophies  winner.tag  winner.startingTrophies  \
# 0                    6590.0  #28RR8PJP0                   6581.0
# 1                    5582.5   #YV9VQUVP                   5592.0
# 2                    5684.0  #LPR2G0Q9L                   5678.0
# 3                    6031.0  #2GL899VCJ                   6035.0
# 4                    5140.0  #9Y2YJPGG2                   5140.0
#
#    winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 0                 31.0            2.0                     4768.0  ...
# 1                 28.0            3.0                     2014.0  ...
# 2                 31.0            3.0                     5304.0  ...
# 3                 29.0            2.0                     3368.0  ...
# 4                 30.0            3.0                     1507.0  ...
#
#                                     loser.cards.list loser.totalcard.level  \
# 0  [26000000, 26000026, 26000030, 26000041, 27000...                   104
# 1  [26000000, 26000003, 26000007, 26000011, 26000...                   104
# 2  [26000011, 26000026, 26000030, 26000041, 27000...                   103
# 3  [26000032, 26000040, 26000041, 26000049, 26000...                   104
# 4  [26000012, 26000024, 26000045, 26000056, 26000...                    93
#
#    loser.troop.count loser.structure.count  loser.spell.count  \
# 0                  4                     1                  3
# 1                  6                     0                  2
# 2                  4                     1                  3
# 3                  6                     1                  1
# 4                  5                     1                  2
#
#    loser.common.count  loser.rare.count  loser.epic.count  \
# 0                   4                 1                 1
# 1                   2                 3                 3
# 2                   3                 2                 2
# 3                   3                 2                 1
# 4                   3                 1                 4
#
#   loser.legendary.count  loser.elixir.average
# 0                     2                 3.125
# 1                     0                 4.125
# 2                     1                 2.875
# 3                     2                 3.375
# 4                     0                 3.875
#
# [5 rows x 74 columns]
#        Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 73492       73492  2020-12-08 23:59:52+00:00  54000050.0   72000006.0
# 73493       73493  2020-12-08 23:59:54+00:00  54000050.0   72000006.0
# 73494       73494  2020-12-08 23:59:56+00:00  54000050.0   72000006.0
# 73495       73495  2020-12-08 23:59:57+00:00  54000050.0   72000006.0
# 73496       73496  2020-12-08 23:59:58+00:00  54000050.0   72000006.0
#
#        average.startingTrophies  winner.tag  winner.startingTrophies  \
# 73492                    5005.5  #P98GYR0Y9                   5004.0
# 73493                    5247.0     #YPGQLG                   5231.0
# 73494                    5171.0   #29V8CQ20                   5191.0
# 73495                    4724.0  #9J20GR28P                   4724.0
# 73496                    4704.0   #QYQL9GCJ                   4701.0
#
#        winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 73492                 30.0            1.0                     5832.0  ...
# 73493                 32.0            2.0                     5832.0  ...
# 73494                 26.0            2.0                     2536.0  ...
# 73495                 30.0            2.0                     5370.0  ...
# 73496                 30.0            1.0                     5304.0  ...
#
#                                         loser.cards.list  \
# 73492  [26000001, 26000004, 26000021, 26000023, 26000...
# 73493  [26000006, 26000032, 26000037, 26000038, 26000...
# 73494  [26000005, 26000018, 26000033, 26000042, 26000...
# 73495  [26000000, 26000006, 26000011, 26000023, 26000...
# 73496  [26000004, 26000017, 26000042, 26000043, 27000...
#
#       loser.totalcard.level  loser.troop.count loser.structure.count  \
# 73492                   104                  5                     1
# 73493                   103                  5                     1
# 73494                   104                  6                     0
# 73495                   104                  7                     0
# 73496                   104                  4                     1
#
#        loser.spell.count  loser.common.count  loser.rare.count  \
# 73492                  2                   2                 3
# 73493                  2                   1                 4
# 73494                  2                   2                 1
# 73495                  1                   3                 2
# 73496                  3                   2                 3
#
#        loser.epic.count loser.legendary.count  loser.elixir.average
# 73492                 1                     2              4.000000
# 73493                 1                     2              3.375000
# 73494                 2                     3              4.250000
# 73495                 1                     2              3.625000
# 73496                 2                     1              4.839286
#
# [5 rows x 74 columns]
# dfAfter head (should start where dfBefore ends):
#        Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 73497       73497  2020-12-09 00:00:00+00:00  54000050.0   72000006.0
# 73498       73498  2020-12-09 00:00:01+00:00  54000050.0   72000006.0
# 73499       73499  2020-12-09 00:00:02+00:00  54000050.0   72000006.0
# 73500       73500  2020-12-09 00:00:04+00:00  54000050.0   72000006.0
# 73501       73501  2020-12-09 00:00:12+00:00  54000050.0   72000006.0
#
#        average.startingTrophies  winner.tag  winner.startingTrophies  \
# 73497                    5407.5  #YPYLQRL0Y                   5426.0
# 73498                    4399.5   #JJ2PPVJ8                   4398.0
# 73499                    4964.0  #8PVL92J88                   4978.0
# 73500                    5546.5   #L08G0GV2                   5529.0
# 73501                    4968.5  #89PR0PJ9P                   4966.0
#
#        winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 73497                 26.0            1.0                     5562.0  ...
# 73498                 30.0            3.0                     5832.0  ...
# 73499                 27.0            1.0                     5832.0  ...
# 73500                 33.0            1.0                     5832.0  ...
# 73501                 30.0            1.0                     5832.0  ...
#
#                                         loser.cards.list  \
# 73497  [26000009, 26000015, 26000042, 26000048, 27000...
# 73498  [26000012, 26000015, 26000026, 26000037, 26000...
# 73499  [26000014, 26000018, 26000041, 27000003, 27000...
# 73500  [26000000, 26000019, 26000032, 26000049, 26000...
# 73501  [26000007, 26000011, 26000014, 26000015, 26000...
#
#       loser.totalcard.level  loser.troop.count loser.structure.count  \
# 73497                   104                  4                     1
# 73498                    73                  7                     0
# 73499                   104                  3                     2
# 73500                   104                  5                     1
# 73501                   104                  7                     0
#
#        loser.spell.count  loser.common.count  loser.rare.count  \
# 73497                  3                   0                 1
# 73498                  1                   1                 0
# 73499                  3                   2                 4
# 73500                  2                   3                 2
# 73501                  1                   0                 4
#
#        loser.epic.count loser.legendary.count  loser.elixir.average
# 73497                 5                     2                 4.375
# 73498                 2                     5                 3.750
# 73499                 2                     0                 4.000
# 73500                 1                     2                 2.625
# 73501                 4                     0                 4.125
#
# [5 rows x 74 columns]
# dfAfter tail:
#         Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 395640      395640  2020-12-15 23:11:57+00:00  54000050.0   72000006.0
# 395641      395641  2020-12-15 23:11:58+00:00  54000050.0   72000006.0
# 395642      395642  2020-12-15 23:11:59+00:00  54000050.0   72000006.0
# 395643      395643  2020-12-15 23:12:01+00:00  54000050.0   72000006.0
# 395644      395644  2020-12-15 23:12:03+00:00  54000050.0   72000006.0
#
#         average.startingTrophies  winner.tag  winner.startingTrophies  \
# 395640                    5241.5  #2YP20RU08                   5230.0
# 395641                    5578.0  #2URGULQRG                   5580.0
# 395642                    4808.5    #22JCPYL                   4813.0
# 395643                    4984.0  #2992PJPG9                   4988.0
# 395644                    4835.0   #C088LYRV                   4827.0
#
#         winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 395640                 31.0            1.0                     5832.0  ...
# 395641                 29.0            1.0                     4709.0  ...
# 395642                 29.0            1.0                     5832.0  ...
# 395643                 29.0            2.0                     4174.0  ...
# 395644                 31.0            2.0                     4340.0  ...
#
#                                          loser.cards.list  \
# 395640  [26000012, 26000017, 26000020, 26000021, 26000...
# 395641  [26000000, 26000014, 26000019, 26000054, 27000...
# 395642  [26000000, 26000017, 26000027, 26000043, 26000...
# 395643  [26000009, 26000015, 26000035, 26000039, 26000...
# 395644  [26000001, 26000007, 26000021, 26000027, 26000...
#
#        loser.totalcard.level  loser.troop.count loser.structure.count  \
# 395640                   104                  6                     1
# 395641                   103                  4                     1
# 395642                    99                  7                     0
# 395643                   101                  5                     0
# 395644                   104                  6                     0
#
#         loser.spell.count  loser.common.count  loser.rare.count  \
# 395640                  1                   3                 2
# 395641                  3                   3                 1
# 395642                  1                   3                 1
# 395643                  3                   0                 1
# 395644                  2                   2                 3
#
#         loser.epic.count loser.legendary.count  loser.elixir.average
# 395640                 2                     1                 4.000
# 395641                 3                     1                 3.625
# 395642                 3                     1                 4.375
# 395643                 5                     2                 4.250
# 395644                 2                     1                 3.625
#
# [5 rows x 74 columns]
